# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot  as plt

# %%
df = pd.read_excel('cleaned_salary_data.xlsx', index_col=0)

# %%
df.head()
# Out:
#                           Salary Estimate  \
# Job Title
# Data Scientist                     53-91
# Healthcare Data Scientist         63-112
# Data Scientist                     80-90
# Data Scientist                     56-97
# Data Scientist                    86-143
#
#                                                              Job Description  \
# Job Title
# Data Scientist             Data Scientist\nLocation: Albuquerque, NM\nEdu...
# Healthcare Data Scientist  What You Will Do:\n\nI. General Summary\n\nThe...
# Data Scientist             KnowBe4, Inc. is a high growth information sec...
# Data Scientist             *Organization and Job ID**\nJob ID: 310709\n\n...
# Data Scientist             Data Scientist\nAffinity Solutions / Marketing...
#
#                            Rating  \
# Job Title
# Data Scientist                3.8
# Healthcare Data Scientist     3.4
# Data Scientist                4.8
# Data Scientist                3.8
# Data Scientist                2.9
#
#                                                                Company Name  \
# Job Title
# Data Scientist                                 ['Tecolote Research', '3.8']
# Healthcare Data Scientist  ['University of Maryland Medical System', '3.4']
# Data Scientist                                           ['KnowBe4', '4.8']
# Data Scientist                                              ['PNNL', '3.8']
# Data Scientist                                ['Affinity Solutions', '2.9']
#
#                                   Location    Headquarters  \
# Job Title
# Data Scientist             Albuquerque, NM      Goleta, CA
# Healthcare Data Scientist    Linthicum, MD   Baltimore, MD
# Data Scientist              Clearwater, FL  Clearwater, FL
# Data Scientist                Richland, WA    Richland, WA
# Data Scientist                New York, NY    New York, NY
#
#                                              Size  Founded  \
# Job Title
# Data Scientist              501 to 1000 employees     1973
# Healthcare Data Scientist        10000+ employees     1984
# Data Scientist              501 to 1000 employees     2010
# Data Scientist             1001 to 5000 employees     1965
# Data Scientist                51 to 200 employees     1998
#
#                             Type of ownership  \
# Job Title
# Data Scientist              Company - Private
# Healthcare Data Scientist  Other Organization
# Data Scientist              Company - Private
# Data Scientist                     Government
# Data Scientist              Company - Private
#
#                                                    Industry  ... min_salary  \
# Job Title                                                    ...
# Data Scientist                          Aerospace & Defense  ...         53
# Healthcare Data Scientist  Health Care Services & Hospitals  ...         63
# Data Scientist                            Security Services  ...         80
# Data Scientist                                       Energy  ...         56
# Data Scientist                      Advertising & Marketing  ...         86
#
#                           max_salary avg_salary  job_state  same_location  \
# Job Title
# Data Scientist                    91       72.0         NM              0
# Healthcare Data Scientist        112       87.5         MD              0
# Data Scientist                    90       85.0         FL              1
# Data Scientist                    97       76.5         WA              1
# Data Scientist                   143      114.5         NY              1
#
#                            age        Job_simp  seniority num_comp  desc_len
# Job Title
# Data Scientist              49  data scientist         na        1      2536
# Healthcare Data Scientist   38  data scientist         na        1      4783
# Data Scientist              12  data scientist         na        1      3461
# Data Scientist              57  data scientist         na        1      3883
# Data Scientist              24  data scientist         na        1      2728
#
# [5 rows x 25 columns]

# %%
df.describe()
# Out:
#            Rating      Founded      hourly  employee_provided  min_salary  \
# count  742.000000   742.000000  742.000000              742.0  742.000000
# mean     3.618868  1837.154987    0.032345                0.0   74.719677
# std      0.801210   497.183763    0.177034                0.0   30.980593
# min     -1.000000    -1.000000    0.000000                0.0   15.000000
# 25%      3.300000  1939.000000    0.000000                0.0   52.000000
# 50%      3.700000  1988.000000    0.000000                0.0   69.500000
# 75%      4.000000  2007.000000    0.000000                0.0   91.000000
# max      5.000000  2019.000000    1.000000                0.0  202.000000
#
#        max_salary  avg_salary  same_location         age  num_comp  \
# count  742.000000  742.000000     742.000000  742.000000     742.0
# mean   128.149596  100.626011       0.557951   48.456873       1.0
# std     45.220324   38.855948       0.496965   53.900445       0.0
# min     16.000000   13.500000       0.000000   -1.000000       1.0
# 25%     96.000000   73.500000       0.000000   13.000000       1.0
# 50%    124.000000   97.500000       1.000000   26.000000       1.0
# 75%    155.000000  122.500000       1.000000   61.000000       1.0
# max    306.000000  254.000000       1.000000  278.000000       1.0
#
#            desc_len
# count    742.000000
# mean    3869.545822
# std     1521.495868
# min      407.000000
# 25%     2801.000000
# 50%     3731.000000
# 75%     4740.000000
# max    10051.000000

# %%
df.columns
# Out:
# Index(['Salary Estimate', 'Job Description', 'Rating', 'Company Name',
#        'Location', 'Headquarters', 'Size', 'Founded', 'Type of ownership',
#        'Industry', 'Sector', 'Revenue', 'Competitors', 'hourly',
#        'employee_provided', 'min_salary', 'max_salary', 'avg_salary',
#        'job_state', 'same_location', 'age', 'Job_simp', 'seniority',
#        'num_comp', 'desc_len'],
#       dtype='object')

# %%
df.Rating.hist()
# Out:
# <Axes: >

# %%
df.avg_salary.hist()
# Out:
# <Axes: >

# %%
df.age.hist()
# Out:
# <Axes: >

# %%
df.desc_len.hist()
# Out:
# <Axes: >

# %%
df.boxplot(column=['avg_salary','age'])
# Out:
# <Axes: >

# %%
df.boxplot(column=['Rating'])
# Out:
# <Axes: >

# %%
corr = df[['age','avg_salary','Rating','desc_len','num_comp']].corr()

# %%
cmap =sns.diverging_palette(220, 10, as_cmap=True)
sns.heatmap(corr,vmax=.3, center=0, cmap=cmap,
            square=True, linewidth=.5, cbar_kws={"shrink": .5})
# Out:
# <Axes: >

# %%
df_cat = df[['Location', 'Headquarters', 'Size','Type of ownership', 'Industry', 'Sector', 'Revenue', 'Company Name', 'job_state','same_location',  'Job_simp', 'seniority']]

# %%
for i in df_cat:
  cat_num = df_cat[i].value_counts()
  print("graph for %s: total = %d" % (i, len(cat_num)))
  chart = sns.barplot(x=cat_num.index, y=cat_num)
  chart.set_xticklabels(chart.get_xticklabels(), rotation=90)# Rotation of xlabel
  plt.show()
# Out:
# graph for Location: total = 200
# C:\Users\SAI\AppData\Local\Temp\ipykernel_4388\598932724.py:5: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   chart.set_xticklabels(chart.get_xticklabels(), rotation=90)# Rotation of xlabel
# graph for Headquarters: total = 198
# C:\Users\SAI\AppData\Local\Temp\ipykernel_4388\598932724.py:5: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   chart.set_xticklabels(chart.get_xticklabels(), rotation=90)# Rotation of xlabel
# graph for Size: total = 9
# C:\Users\SAI\AppData\Local\Temp\ipykernel_4388\598932724.py:5: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   chart.set_xticklabels(chart.get_xticklabels(), rotation=90)# Rotation of xlabel
# graph for Type of ownership: total = 11
# C:\Users\SAI\AppData\Local\Temp\ipykernel_4388\598932724.py:5: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   chart.set_xticklabels(chart.get_xticklabels(), rotation=90)# Rotation of xlabel
# graph for Industry: total = 60
# C:\Users\SAI\AppData\Local\Temp\ipykernel_4388\598932724.py:5: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   chart.set_xticklabels(chart.get_xticklabels(), rotation=90)# Rotation of xlabel
# graph for Sector: total = 25
# C:\Users\SAI\AppData\Local\Temp\ipykernel_4388\598932724.py:5: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   chart.set_xticklabels(chart.get_xticklabels(), rotation=90)# Rotation of xlabel
# C:\Users\SAI\AppData\Local\Temp\ipykernel_4388\598932724.py:5: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   chart.set_xticklabels(chart.get_xticklabels(), rotation=90)# Rotation of xlabel
# graph for Revenue: total = 14
# graph for Company Name: total = 343
# C:\Users\SAI\AppData\Local\Temp\ipykernel_4388\598932724.py:5: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   chart.set_xticklabels(chart.get_xticklabels(), rotation=90)# Rotation of xlabel
# graph for job_state: total = 38
# C:\Users\SAI\AppData\Local\Temp\ipykernel_4388\598932724.py:5: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   chart.set_xticklabels(chart.get_xticklabels(), rotation=90)# Rotation of xlabel
# C:\Users\SAI\AppData\Local\Temp\ipykernel_4388\598932724.py:5: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   chart.set_xticklabels(chart.get_xticklabels(), rotation=90)# Rotation of xlabel
# graph for same_location: total = 2
# graph for Job_simp: total = 7
# C:\Users\SAI\AppData\Local\Temp\ipykernel_4388\598932724.py:5: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   chart.set_xticklabels(chart.get_xticklabels(), rotation=90)# Rotation of xlabel
# graph for seniority: total = 2
# C:\Users\SAI\AppData\Local\Temp\ipykernel_4388\598932724.py:5: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   chart.set_xticklabels(chart.get_xticklabels(), rotation=90)# Rotation of xlabel

# %%
   for i in df_cat[['Location','Headquarters','Company Name']].columns:
    cat_num = df_cat[i].value_counts()[:20]
    print("graph for %s: total = %d" %(i, len(cat_num)))
    chart = sns.barplot(x=cat_num.index, y=cat_num)
    chart.set_xticklabels(chart.get_xticklabels(), rotation=90)
    plt.show()
# Out:
# graph for Location: total = 20
# C:\Users\SAI\AppData\Local\Temp\ipykernel_4388\4219716801.py:5: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   chart.set_xticklabels(chart.get_xticklabels(), rotation=90)
# graph for Headquarters: total = 20
# C:\Users\SAI\AppData\Local\Temp\ipykernel_4388\4219716801.py:5: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   chart.set_xticklabels(chart.get_xticklabels(), rotation=90)
# graph for Company Name: total = 20
# C:\Users\SAI\AppData\Local\Temp\ipykernel_4388\4219716801.py:5: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   chart.set_xticklabels(chart.get_xticklabels(), rotation=90)

# %%
df.columns
# Out:
# Index(['Salary Estimate', 'Job Description', 'Rating', 'Company Name',
#        'Location', 'Headquarters', 'Size', 'Founded', 'Type of ownership',
#        'Industry', 'Sector', 'Revenue', 'Competitors', 'hourly',
#        'employee_provided', 'min_salary', 'max_salary', 'avg_salary',
#        'job_state', 'same_location', 'age', 'Job_simp', 'seniority',
#        'num_comp', 'desc_len'],
#       dtype='object')

# %%
pd.pivot_table(df,index='Job_simp',values ='avg_salary').sort_values('avg_salary',ascending=False)
# Out:
#                 avg_salary
# Job_simp
# director        168.607143
# mle             126.431818
# data scientist  117.564516
# data engineer   105.403361
# na               84.853261
# manager          84.022727
# analyst          65.857843

# %% [markdown]
# 1.Data Science Directors have the most salary followed but ML engineers and then data scientists

# %%
pd.pivot_table(df,index=['Job_simp','seniority'], values ='avg_salary').sort_values('avg_salary',ascending=False)
# Out:
#                           avg_salary
# Job_simp       seniority
# director       na         168.607143
# data scientist senior     134.524390
# mle            senior     127.000000
#                na         126.218750
# data engineer  senior     123.638889
# data scientist na         110.505076
# na             senior     110.204545
# data engineer  na          97.493976
# manager        na          84.022727
# analyst        senior      79.092593
# na             na          76.885714
# analyst        na          61.093333

# %%
pd.pivot_table(df,index = ['job_state','Job_simp'], values = 'avg_salary').sort_values('job_state',ascending=False)
# Out:
#                             avg_salary
# job_state   Job_simp
# WI          na               54.000000
#             data scientist  113.500000
#             analyst          58.833333
# WA          na               97.500000
#             data scientist   99.764706
#             analyst          54.500000
# VA          na               79.300000
#             mle              87.000000
#             data scientist  108.416667
#             data engineer    96.900000
#             analyst          71.583333
# UT          data engineer   100.333333
#             analyst          54.750000
#             data scientist  140.500000
# TX          na               41.285714
#             data scientist  100.730769
#             data engineer   113.062500
# TN          data scientist   96.000000
#             data engineer   100.950000
#             analyst          13.500000
# SC          na               60.500000
# RI          analyst         100.000000
# PA          manager         109.666667
#             data engineer    91.500000
#             data scientist  113.333333
#             analyst          62.750000
#             mle             120.500000
#             na               76.062500
# OR          data scientist   98.500000
#             data engineer    73.000000
# OH          na               91.166667
#             data scientist  105.285714
#             analyst          53.875000
# NY          na               81.583333
#             mle             125.000000
#             data scientist  115.250000
#             data engineer    86.375000
#             analyst          65.607143
# NM          data scientist   74.333333
# NJ          data scientist  106.875000
#             analyst          83.583333
#             data engineer   112.000000
#             manager         109.500000
#             director        161.500000
#             na               82.500000
# NE          na               41.000000
# NC          na               90.916667
#             data scientist  117.000000
#             data engineer   104.250000
# MO          na               72.333333
#             manager          40.500000
#             data scientist  127.666667
#             analyst          61.000000
# MN          data engineer    95.000000
#             analyst          76.000000
# MI          data scientist  106.625000
#             manager          87.500000
# MD          na               88.750000
#             data scientist  109.115385
#             data engineer   109.000000
#             analyst          80.666667
# MA          na              107.478261
#             manager          71.900000
#             director        117.833333
#             data scientist  113.750000
#             data engineer   107.291667
#             analyst          59.125000
# Los Angeles data scientist  107.500000
# LA          analyst          48.000000
#             data engineer    70.500000
#             na               20.000000
# KY          na              103.500000
#             data scientist   84.000000
# KS          mle              87.000000
# IN          na               69.000000
#             data scientist   84.500000
#             data engineer   114.500000
# IL          analyst          66.500000
#             na               57.166667
#             mle             133.000000
#             director        221.750000
#             data scientist  117.233333
#             data engineer    96.125000
# ID          analyst          56.250000
# IA          analyst          43.000000
#             data engineer   102.833333
# GA          data scientist   81.333333
#             na               80.000000
# FL          data scientist   97.357143
#             data engineer    91.833333
#             analyst          47.500000
# DE          na               27.500000
# DC          data scientist  149.000000
#             data engineer    85.000000
#             analyst          63.500000
# CT          na               62.500000
#             data scientist   84.000000
# CO          mle             100.500000
#             data engineer    99.000000
#             analyst          29.500000
#             na               31.500000
#             data scientist  108.666667
# CA          na               99.907407
#             mle             177.300000
#             manager          80.611111
#             data scientist  143.044776
#             data engineer   129.540000
#             analyst          85.250000
# AZ          data scientist   69.500000
#             data engineer    79.500000
#             analyst          55.000000
#             na              124.500000
# AL          na               43.750000
#             data engineer    65.000000
#             analyst          62.200000

# %%
#to see the full datafame

pd.options.display.max_rows
pd.set_option('display.max_rows', None)
pd.pivot_table(df,index = ['job_state','Job_simp'], values = 'avg_salary').sort_values('job_state',ascending=False)
# Out:
#                             avg_salary
# job_state   Job_simp
# WI          na               54.000000
#             data scientist  113.500000
#             analyst          58.833333
# WA          na               97.500000
#             data scientist   99.764706
#             analyst          54.500000
# VA          na               79.300000
#             mle              87.000000
#             data scientist  108.416667
#             data engineer    96.900000
#             analyst          71.583333
# UT          data engineer   100.333333
#             analyst          54.750000
#             data scientist  140.500000
# TX          na               41.285714
#             data scientist  100.730769
#             data engineer   113.062500
# TN          data scientist   96.000000
#             data engineer   100.950000
#             analyst          13.500000
# SC          na               60.500000
# RI          analyst         100.000000
# PA          manager         109.666667
#             data engineer    91.500000
#             data scientist  113.333333
#             analyst          62.750000
#             mle             120.500000
#             na               76.062500
# OR          data scientist   98.500000
#             data engineer    73.000000
# OH          na               91.166667
#             data scientist  105.285714
#             analyst          53.875000
# NY          na               81.583333
#             mle             125.000000
#             data scientist  115.250000
#             data engineer    86.375000
#             analyst          65.607143
# NM          data scientist   74.333333
# NJ          data scientist  106.875000
#             analyst          83.583333
#             data engineer   112.000000
#             manager         109.500000
#             director        161.500000
#             na               82.500000
# NE          na               41.000000
# NC          na               90.916667
#             data scientist  117.000000
#             data engineer   104.250000
# MO          na               72.333333
#             manager          40.500000
#             data scientist  127.666667
#             analyst          61.000000
# MN          data engineer    95.000000
#             analyst          76.000000
# MI          data scientist  106.625000
#             manager          87.500000
# MD          na               88.750000
#             data scientist  109.115385
#             data engineer   109.000000
#             analyst          80.666667
# MA          na              107.478261
#             manager          71.900000
#             director        117.833333
#             data scientist  113.750000
#             data engineer   107.291667
#             analyst          59.125000
# Los Angeles data scientist  107.500000
# LA          analyst          48.000000
#             data engineer    70.500000
#             na               20.000000
# KY          na              103.500000
#             data scientist   84.000000
# KS          mle              87.000000
# IN          na               69.000000
#             data scientist   84.500000
#             data engineer   114.500000
# IL          analyst          66.500000
#             na               57.166667
#             mle             133.000000
#             director        221.750000
#             data scientist  117.233333
#             data engineer    96.125000
# ID          analyst          56.250000
# IA          analyst          43.000000
#             data engineer   102.833333
# GA          data scientist   81.333333
#             na               80.000000
# FL          data scientist   97.357143
#             data engineer    91.833333
#             analyst          47.500000
# DE          na               27.500000
# DC          data scientist  149.000000
#             data engineer    85.000000
#             analyst          63.500000
# CT          na               62.500000
#             data scientist   84.000000
# CO          mle             100.500000
#             data engineer    99.000000
#             analyst          29.500000
#             na               31.500000
#             data scientist  108.666667
# CA          na               99.907407
#             mle             177.300000
#             manager          80.611111
#             data scientist  143.044776
#             data engineer   129.540000
#             analyst          85.250000
# AZ          data scientist   69.500000
#             data engineer    79.500000
#             analyst          55.000000
#             na              124.500000
# AL          na               43.750000
#             data engineer    65.000000
#             analyst          62.200000

# %%
pd.pivot_table(df,index=['job_state','Job_simp'], values='avg_salary').sort_values('job_state',ascending=False)[:10]
# Out:
#                           avg_salary
# job_state Job_simp
# WI        na               54.000000
#           data scientist  113.500000
#           analyst          58.833333
# WA        na               97.500000
#           data scientist   99.764706
#           analyst          54.500000
# VA        na               79.300000
#           mle              87.000000
#           data scientist  108.416667
#           data engineer    96.900000

# %% [markdown]
# Wisconsin have the most data science jobs followed by Washington and then Virginia

# %%
pd.pivot_table(df,index = ['job_state','Job_simp'], values = 'avg_salary').sort_values('avg_salary',ascending=False)[:10]
# Out:
#                           avg_salary
# job_state Job_simp
# IL        director        221.750000
# CA        mle             177.300000
# NJ        director        161.500000
# DC        data scientist  149.000000
# CA        data scientist  143.044776
# UT        data scientist  140.500000
# IL        mle             133.000000
# CA        data engineer   129.540000
# MO        data scientist  127.666667
# NY        mle             125.000000

# %% [markdown]
# Compare by salary, illinios offers most salary

# %%
pd.options.display.max_rows
pd.set_option('display.max_rows',None)
pd.pivot_table(df,index = ['job_state','Job_simp'], values = 'avg_salary',aggfunc='count').sort_values('job_state',ascending=False) # for counts aggfunc
# Out:
#                             avg_salary
# job_state   Job_simp
# WI          na                       4
#             data scientist           3
#             analyst                  3
# WA          na                       1
#             data scientist          17
#             analyst                  3
# VA          na                       5
#             mle                      2
#             data scientist          18
#             data engineer           10
#             analyst                  6
# UT          data engineer            3
#             analyst                  4
#             data scientist           3
# TX          na                       7
#             data scientist          13
#             data engineer            8
# TN          data scientist           1
#             data engineer           10
#             analyst                  2
# SC          na                       1
# RI          analyst                  1
# PA          manager                  3
#             data engineer            1
#             data scientist           6
#             analyst                  8
#             mle                      7
#             na                       8
# OR          data scientist           3
#             data engineer            1
# OH          na                       3
#             data scientist           7
#             analyst                  4
# NY          na                      12
#             mle                      2
#             data scientist          40
#             data engineer            4
#             analyst                 14
# NM          data scientist           3
# NJ          data scientist           4
#             analyst                  6
#             data engineer            2
#             manager                  2
#             director                 2
#             na                       1
# NE          na                       4
# NC          na                      12
#             data scientist           3
#             data engineer            6
# MO          na                       3
#             manager                  1
#             data scientist           3
#             analyst                  2
# MN          data engineer            1
#             analyst                  1
# MI          data scientist           4
#             manager                  2
# MD          na                      16
#             data scientist          13
#             data engineer            3
#             analyst                  3
# MA          na                      46
#             manager                  5
#             director                 6
#             data scientist          30
#             data engineer           12
#             analyst                  4
# Los Angeles data scientist           1
# LA          analyst                  1
#             data engineer            2
#             na                       1
# KY          na                       4
#             data scientist           2
# KS          mle                      3
# IN          na                       4
#             data scientist           2
#             data engineer            4
# IL          analyst                  3
#             na                       6
#             mle                      2
#             director                 6
#             data scientist          15
#             data engineer            8
# ID          analyst                  2
# IA          analyst                  2
#             data engineer            3
# GA          data scientist           3
#             na                       3
# FL          data scientist           7
#             data engineer            3
#             analyst                  6
# DE          na                       6
# DC          data scientist           5
#             data engineer            4
#             analyst                  2
# CT          na                       3
#             data scientist           2
# CO          mle                      1
#             data engineer            3
#             analyst                  1
#             na                       3
#             data scientist           3
# CA          na                      27
#             mle                      5
#             manager                  9
#             data scientist          67
#             data engineer           25
#             analyst                 18
# AZ          data scientist           1
#             data engineer            5
#             analyst                  1
#             na                       2
# AL          na                       2
#             data engineer            1
#             analyst                  5

# %%
pd.pivot_table(df[df.Job_simp == 'data scientist'], index='job_state',values='avg_salary').sort_values('avg_salary',ascending=False)
# Out:
#              avg_salary
# job_state
# DC           149.000000
# CA           143.044776
# UT           140.500000
# MO           127.666667
# IL           117.233333
# NC           117.000000
# NY           115.250000
# MA           113.750000
# WI           113.500000
# PA           113.333333
# MD           109.115385
# CO           108.666667
# VA           108.416667
# Los Angeles  107.500000
# NJ           106.875000
# MI           106.625000
# OH           105.285714
# TX           100.730769
# WA            99.764706
# OR            98.500000
# FL            97.357143
# TN            96.000000
# IN            84.500000
# KY            84.000000
# CT            84.000000
# GA            81.333333
# NM            74.333333
# AZ            69.500000

# %%
pd.pivot_table(df, index = 'Industry', values = 'avg_salary').sort_values('avg_salary',ascending=False)[:10]
# Out:
#                                           avg_salary
# Industry
# Other Retail Stores                       163.500000
# Motion Picture Production & Distribution  146.000000
# Financial Analytics & Research            145.125000
# Health, Beauty, & Fitness                 139.500000
# Telecommunications Services               131.500000
# Brokerage Services                        129.000000
# Auctions & Galleries                      128.000000
# Internet                                  123.810345
# Investment Banking & Asset Management     118.400000
# TV Broadcast & Cable Networks             117.750000

# %% [markdown]
# ### The chart above shows the top ten industry paying the highest

# %%
print(df.columns)
# Out:
# Index(['Salary Estimate', 'Job Description', 'Rating', 'Company Name',
#        'Location', 'Headquarters', 'Size', 'Founded', 'Type of ownership',
#        'Industry', 'Sector', 'Revenue', 'Competitors', 'hourly',
#        'employee_provided', 'min_salary', 'max_salary', 'avg_salary',
#        'job_state', 'same_location', 'age', 'Job_simp', 'seniority',
#        'num_comp', 'desc_len'],
#       dtype='object')

# %%
df_pivots = df[['Rating', 'Industry', 'Sector', 'Revenue', 'num_comp', 'hourly', 'employee_provided', 'Type of ownership', 'avg_salary']]

# %%
pd.pivot_table(df_pivots, index='Revenue', values='avg_salary', aggfunc='count')
# Out:
#                                   avg_salary
# Revenue
# $1 to $2 billion (USD)                    60
# $1 to $5 million (USD)                     8
# $10 to $25 million (USD)                  32
# $10+ billion (USD)                       124
# $100 to $500 million (USD)                91
# $2 to $5 billion (USD)                    39
# $25 to $50 million (USD)                  40
# $5 to $10 billion (USD)                   19
# $5 to $10 million (USD)                   18
# $50 to $100 million (USD)                 46
# $500 million to $1 billion (USD)          57
# -1                                         1
# Less than $1 million (USD)                 4
# Unknown / Non-Applicable                 203
